# %% [markdown]
# ###### Name: Deepak Vadithala
# ###### Course: MSc Data Science
# ###### Project Name: MOOC Recommender System
#
# ##### Notes:
# This notebook contains the analysis of the **Google's Word2Vec** model. This model is trained on the news articles.
# two variable **(Role and Skill Scores)** is used to predict the course category.
# Skill Score is calculated using the similarity between the skills from LinkedIn compared with the course description with keywords from Coursera.
#
#
# *Model Source Code Path: /mooc-recommender/Model/Cosine_Distance.py*
#
# *Github Repo: https://github.com/iamdv/mooc-recommender*

# %%
# **************************** IMPORTANT ****************************
'''
This cell configuration settings for the Notebook. 
You can run one role at a time to evaluate the performance of the model
Change the variable names to run for multiple roles

In this model:
1. Google word2vec model has two variables Roles and Skills with 
50% weightage for each
'''

# *******************************************************************
# For each role a list of category names are grouped. 
# Please don't change these variables

label_DataScientist = ['Data Science','Data Analysis','Data Mining','Data Visualization']

label_SoftwareDevelopment = ['Software Development','Computer Science',
                           'Programming Languages', 'Algorithms and Data Structures', 
                           'Information Technology']


label_DatabaseAdministrator = ['Databases']

label_Cybersecurity = ['Cybersecurity']

label_FinancialAccountant = ['Finance', 'Accounting']

label_MachineLearning = ['Machine Learning', 'Deep Learning']

label_Musician = ['Music']

label_Dietitian = ['Nutrition & Wellness', 'Health & Medicine']

            
# *******************************************************************


# *******************************************************************
# Environment and Config Variables. Change these variables as per the requirement.

my_fpath_courses = "../Data/main_coursera.csv"

my_fpath_skills_DataScientist = "../Data/Word2Vec-Google/Word2VecGoogle_DataScientist.csv"

my_fpath_skills_SoftwareDevelopment = "../Data/Word2Vec-Google/Word2VecGoogle_SoftwareDevelopment.csv" 

my_fpath_skills_DatabaseAdministrator = "../Data/Word2Vec-Google/Word2VecGoogle_DatabaseAdministrator.csv"

my_fpath_skills_Cybersecurity = "../Data/Word2Vec-Google/Word2VecGoogle_Cybersecurity.csv"

my_fpath_skills_FinancialAccountant = "../Data/Word2Vec-Google/Word2VecGoogle_FinancialAccountant.csv"

my_fpath_skills_MachineLearning = "../Data/Word2Vec-Google/Word2VecGoogle_MachineLearning.csv"

my_fpath_skills_Musician = "../Data/Word2Vec-Google/Word2VecGoogle_Musician.csv"

my_fpath_skills_Dietitian = "../Data/Word2Vec-Google/Word2VecGoogle_Dietitian.csv"


# *******************************************************************


# *******************************************************************
# Weighting Variables. Change them as per the requirement.
# Role score is not applicable for Google's Word2Vec model.

my_role_weight = 0.5

my_skill_weight = 0.5

my_threshold = 0.37

# *******************************************************************

# %%
# Importing required modules/packages

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk, string
import string
import csv
import json

# %%
# Downloading the stopwords like i, me, and, is, the etc.

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/DV/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Loading courses and skills data from the CSV files

df_courses = pd.read_csv(my_fpath_courses)

df_DataScientist = pd.read_csv(my_fpath_skills_DataScientist)
df_DataScientist = df_DataScientist.drop('Role', 1)
df_DataScientist.columns = ['Course Id', 'DataScientist_Skill_Score', 'DataScientist_Role_Score', 'DataScientist_Keyword_Score']

df_SoftwareDevelopment = pd.read_csv(my_fpath_skills_SoftwareDevelopment)
df_SoftwareDevelopment = df_SoftwareDevelopment.drop('Role', 1)
df_SoftwareDevelopment.columns = ['Course Id','SoftwareDevelopment_Skill_Score', 'SoftwareDevelopment_Role_Score', 'SoftwareDevelopment_Keyword_Score']

df_DatabaseAdministrator = pd.read_csv(my_fpath_skills_DatabaseAdministrator)
df_DatabaseAdministrator = df_DatabaseAdministrator.drop('Role', 1)
df_DatabaseAdministrator.columns = ['Course Id','DatabaseAdministrator_Skill_Score', 'DatabaseAdministrator_Role_Score', 'DatabaseAdministrator_Keyword_Score']

df_Cybersecurity = pd.read_csv(my_fpath_skills_Cybersecurity)
df_Cybersecurity = df_Cybersecurity.drop('Role', 1)
df_Cybersecurity.columns = ['Course Id','Cybersecurity_Skill_Score', 'Cybersecurity_Role_Score', 'Cybersecurity_Keyword_Score']

df_FinancialAccountant = pd.read_csv(my_fpath_skills_FinancialAccountant)
df_FinancialAccountant = df_FinancialAccountant.drop('Role', 1)
df_FinancialAccountant.columns = ['Course Id','FinancialAccountant_Skill_Score', 'FinancialAccountant_Role_Score', 'FinancialAccountant_Keyword_Score']

df_MachineLearning = pd.read_csv(my_fpath_skills_MachineLearning)
df_MachineLearning = df_MachineLearning.drop('Role', 1)
df_MachineLearning.columns = ['Course Id','MachineLearning_Skill_Score', 'MachineLearning_Role_Score', 'MachineLearning_Keyword_Score']

df_Musician = pd.read_csv(my_fpath_skills_Musician)
df_Musician = df_Musician.drop('Role', 1)
df_Musician.columns = ['Course Id','Musician_Skill_Score', 'Musician_Role_Score', 'Musician_Keyword_Score']

df_Dietitian = pd.read_csv(my_fpath_skills_Dietitian)
df_Dietitian = df_Dietitian.drop('Role', 1)
df_Dietitian.columns = ['Course Id','Dietitian_Skill_Score', 'Dietitian_Role_Score','Dietitian_Keyword_Score']

df_Psychologist = pd.read_csv(my_fpath_skills_Psychologist)
df_Psychologist = df_Psychologist.drop('Role', 1)
df_Psychologist.columns = ['Course Id','Psychologist_Skill_Score', 'Psychologist_Role_Score', 'Psychologist_Keyword_Score']

# %%
# Merging the csv files

df_cosdist = df_DataScientist.merge(df_SoftwareDevelopment, on = 'Course Id', how = 'outer')

df_cosdist = df_cosdist.merge(df_DatabaseAdministrator, on = 'Course Id', how = 'outer')

df_cosdist = df_cosdist.merge(df_Cybersecurity, on = 'Course Id', how = 'outer')

df_cosdist = df_cosdist.merge(df_FinancialAccountant, on = 'Course Id', how = 'outer')

df_cosdist = df_cosdist.merge(df_MachineLearning, on = 'Course Id', how = 'outer')

df_cosdist = df_cosdist.merge(df_Musician, on = 'Course Id', how = 'outer')

df_cosdist = df_cosdist.merge(df_Dietitian, on = 'Course Id', how = 'outer')

df_cosdist = df_cosdist.merge(df_Psychologist, on = 'Course Id', how = 'outer')

# %%
# Exploring data dimensionality, feature names, and feature types.

print(df_courses.shape,"\n")

print(df_cosdist.shape,"\n")

print(df_courses.columns, "\n")

print(df_cosdist.shape,"\n")

print(df_courses.describe(), "\n")

print(df_cosdist.describe(), "\n")
# Out:
# (2213, 19)
#
# (2213, 28)
#
# Index(['Unnamed: 0', 'Course Id', 'Course Name', 'Course Description', 'Slug',
#        'Provider', 'Universities/Institutions', 'Parent Subject',
#        'Child Subject', 'Category', 'Url', 'Length', 'Language',
#        'Credential Name', 'Rating', 'Number of Ratings', 'Certificate',
#        'Workload', 'Course Keywords'],
#       dtype='object')
#
# (2213, 28)
#
#         Unnamed: 0    Course Id      Length       Rating  Number of Ratings  \
# count  2213.000000  2213.000000  964.000000  2213.000000        2213.000000
# mean   1106.000000  4816.998192    6.063278     2.352785          10.321735
# std     638.982394  3033.878865    2.724669     2.129134         110.680382
# min       0.000000   303.000000    1.000000     0.000000           0.000000
# 25%     553.000000  1829.000000    4.000000     0.000000           0.000000
# 50%    1106.000000  4880.000000    6.000000     3.000000           1.000000
# 75%    1659.000000  7329.000000    7.000000     4.428571           4.000000
# max    2212.000000  9969.000000   47.000000     5.000000        3008.000000
#
#        Certificate
# count       2089.0
# mean           1.0
# std            0.0
# min            1.0
# 25%            1.0
# 50%            1.0
# 75%            1.0
# max            1.0
#
#          Course Id  DataScientist_Skill_Score  DataScientist_Role_Score  \
# count  2213.000000                2213.000000               2213.000000
# mean   4816.998192                   0.253603                  0.202148
# std    3033.878865                   0.063825                  0.095905
# min     303.000000                   0.073427                 -0.045646
# 25%    1829.000000                   0.209730                  0.136829
# 50%    4880.000000                   0.246833                  0.190079
# 75%    7329.000000                   0.290165                  0.253134
# max    9969.000000                   0.496512                  0.684108
#
#        DataScientist_Keyword_Score  SoftwareDevelopment_Skill_Score  \
# count                  2213.000000                      2213.000000
# mean                      0.091181                         0.387198
# std                       0.059478                         0.084046
# min                      -0.063642                         0.102160
# 25%                       0.050196                         0.325518
# 50%                       0.088732                         0.383269
# 75%                       0.125501                         0.440745
# max                       0.396320                         0.700534
#
#        SoftwareDevelopment_Role_Score  SoftwareDevelopment_Keyword_Score  \
# count                     2213.000000                        2213.000000
# mean                         0.270533                           0.120804
# std                          0.123348                           0.116932
# min                         -0.024631                          -0.100123
# 25%                          0.181528                           0.032989
# 50%                          0.254739                           0.093796
# 75%                          0.349016                           0.193437
# max                          0.726558                           0.659895
#
#        DatabaseAdministrator_Skill_Score  DatabaseAdministrator_Role_Score  \
# count                        2213.000000                       2213.000000
# mean                            0.223889                          0.213700
# std                             0.062702                          0.102178
# min                             0.044565                         -0.024762
# 25%                             0.179406                          0.141179
# 50%                             0.211521                          0.200258
# 75%                             0.257764                          0.271785
# max                             0.484228                          0.707394
#
#        DatabaseAdministrator_Keyword_Score             ...              \
# count                          2213.000000             ...
# mean                              0.148530             ...
# std                               0.097067             ...
# min                              -0.124045             ...
# 25%                               0.080847             ...
# 50%                               0.138213             ...
# 75%                               0.207535             ...
# max                               0.627908             ...
#
#        MachineLearning_Keyword_Score  Musician_Skill_Score  \
# count                    2213.000000           2213.000000
# mean                        0.098372              0.234268
# std                         0.060126              0.060516
# min                        -0.080490              0.060548
# 25%                         0.059618              0.199681
# 50%                         0.094563              0.227106
# 75%                         0.135300              0.258019
# max                         0.620310              0.643528
#
#        Musician_Role_Score  Musician_Keyword_Score  Dietitian_Skill_Score  \
# count          2213.000000             2213.000000            2213.000000
# mean              0.114262                0.097471               0.258961
# std               0.083243                0.075950               0.075362
# min              -0.067947               -0.070993               0.005550
# 25%               0.060388                0.047330               0.211049
# 50%               0.099685                0.084650               0.248664
# 75%               0.150736                0.133394               0.294546
# max               0.643383                0.560303               0.758306
#
#        Dietitian_Role_Score  Dietitian_Keyword_Score  \
# count           2213.000000              2213.000000
# mean               0.210623                 0.233843
# std                0.102585                 0.111411
# min               -0.032185                -0.060747
# 25%                0.139227                 0.159844
# 50%                0.200446                 0.223151
# 75%                0.267689                 0.294443
# max                0.684655                 0.833940
#
#        Psychologist_Skill_Score  Psychologist_Role_Score  \
# count               2213.000000              2213.000000
# mean                   0.223754                 0.148925
# std                    0.064369                 0.089864
# min                    0.056846                -0.075064
# 25%                    0.180307                 0.086983
# 50%                    0.212267                 0.137724
# 75%                    0.255775                 0.195719
# max                    0.528828                 0.630743
#
#        Psychologist_Keyword_Score
# count                 2213.000000
# mean                     0.130790
# std                      0.085752
# min                     -0.079583
# 25%                      0.075441
# 50%                      0.120283
# 75%                      0.175208
# max                      0.546818
#
# [8 rows x 28 columns]

# %%
# Quick check to see if the dataframe showing the right results

df_cosdist.head(20)
# Out:
#     Course Id  DataScientist_Skill_Score  DataScientist_Role_Score  \
# 0         303                   0.353896                  0.218317
# 1         305                   0.248907                  0.201266
# 2         306                   0.196352                  0.111541
# 3         307                   0.325023                  0.269903
# 4         308                   0.268324                  0.177796
# 5         309                   0.346725                  0.279909
# 6         316                   0.330795                  0.341219
# 7         317                   0.281024                  0.177137
# 8         318                   0.274875                  0.276595
# 9         322                   0.337485                  0.187397
# 10        328                   0.279452                  0.142453
# 11        329                   0.341033                  0.043958
# 12        331                   0.228128                  0.170804
# 13        332                   0.314243                  0.247797
# 14        333                   0.310784                  0.240063
# 15        334                   0.290789                  0.272520
# 16        335                   0.266535                  0.250984
# 17        336                   0.294859                  0.184603
# 18        337                   0.224954                  0.165699
# 19        338                   0.391411                  0.283600
#
#     DataScientist_Keyword_Score  SoftwareDevelopment_Skill_Score  \
# 0                      0.006389                         0.499727
# 1                      0.060863                         0.671046
# 2                      0.028367                         0.462116
# 3                      0.192762                         0.461995
# 4                      0.096390                         0.424911
# 5                      0.093165                         0.451475
# 6                      0.076157                         0.401275
# 7                      0.065165                         0.361162
# 8                      0.090191                         0.479362
# 9                      0.028805                         0.404149
# 10                     0.052790                         0.478188
# 11                    -0.037296                         0.434852
# 12                     0.056464                         0.383312
# 13                     0.041025                         0.410811
# 14                     0.063495                         0.382298
# 15                     0.107053                         0.166172
# 16                     0.072003                         0.456293
# 17                     0.091086                         0.401788
# 18                     0.136800                         0.353274
# 19                     0.051610                         0.440638
#
#     SoftwareDevelopment_Role_Score  SoftwareDevelopment_Keyword_Score  \
# 0                         0.407900                           0.286107
# 1                         0.637541                           0.339763
# 2                         0.177365                           0.022605
# 3                         0.365222                           0.234099
# 4                         0.171458                           0.070023
# 5                         0.406482                           0.310806
# 6                         0.225375                           0.133911
# 7                         0.201478                           0.083905
# 8                         0.401717                           0.237797
# 9                         0.291805                           0.082941
# 10                        0.419503                           0.363234
# 11                        0.217973                           0.098241
# 12                        0.247410                           0.228630
# 13                        0.404793                           0.273294
# 14                        0.424175                           0.303408
# 15                        0.076607                           0.021992
# 16                        0.352385                           0.129673
# 17                        0.293944                           0.111024
# 18                        0.240544                           0.051310
# 19                        0.279707                           0.099758
#
#     DatabaseAdministrator_Skill_Score  DatabaseAdministrator_Role_Score  \
# 0                            0.481017                          0.552069
# 1                            0.326477                          0.478538
# 2                            0.177970                          0.172532
# 3                            0.318370                          0.290179
# 4                            0.251495                          0.102554
# 5                            0.311971                          0.405204
# 6                            0.263690                          0.267757
# 7                            0.204727                          0.168023
# 8                            0.337210                          0.443668
# 9                            0.251568                          0.248627
# 10                           0.296226                          0.338146
# 11                           0.269069                          0.147513
# 12                           0.179512                          0.234513
# 13                           0.282210                          0.317670
# 14                           0.240926                          0.325942
# 15                           0.160216                          0.235394
# 16                           0.240807                          0.315046
# 17                           0.237564                          0.229430
# 18                           0.206853                          0.162286
# 19                           0.309920                          0.381238
#
#     DatabaseAdministrator_Keyword_Score             ...              \
# 0                              0.239622             ...
# 1                              0.337813             ...
# 2                              0.141302             ...
# 3                              0.158531             ...
# 4                              0.157861             ...
# 5                              0.389088             ...
# 6                              0.107805             ...
# 7                              0.096344             ...
# 8                              0.275484             ...
# 9                              0.173421             ...
# 10                             0.339118             ...
# 11                             0.202014             ...
# 12                             0.268659             ...
# 13                             0.220243             ...
# 14                             0.278033             ...
# 15                             0.101995             ...
# 16                             0.165824             ...
# 17                             0.166148             ...
# 18                             0.158544             ...
# 19                             0.223544             ...
#
#     MachineLearning_Keyword_Score  Musician_Skill_Score  Musician_Role_Score  \
# 0                       -0.009980              0.113307             0.009469
# 1                        0.070378              0.238268             0.126894
# 2                       -0.022811              0.201262             0.104183
# 3                        0.102171              0.201187             0.136207
# 4                        0.158385              0.267893             0.094709
# 5                        0.072626              0.193436             0.008280
# 6                        0.047848              0.186473             0.035255
# 7                        0.122020              0.253335             0.165166
# 8                        0.001999              0.171764             0.089439
# 9                        0.100462              0.200777             0.116844
# 10                      -0.032515              0.230577             0.066293
# 11                       0.062383              0.191229            -0.017836
# 12                       0.079690              0.213796             0.095460
# 13                       0.141767              0.178933             0.098779
# 14                       0.117289              0.150522             0.066806
# 15                       0.011992              0.060548             0.026257
# 16                       0.078196              0.266810             0.079798
# 17                       0.050593              0.271307             0.163960
# 18                       0.040652              0.258313             0.148593
# 19                       0.166219              0.201151             0.062461
#
#     Musician_Keyword_Score  Dietitian_Skill_Score  Dietitian_Role_Score  \
# 0                 0.031942               0.158573              0.129606
# 1                 0.102302               0.167242              0.123262
# 2                 0.093264               0.208029              0.163249
# 3                 0.161853               0.236696              0.216953
# 4                 0.060037               0.226828              0.123050
# 5                 0.010410               0.216048              0.124020
# 6                -0.010463               0.238093              0.254985
# 7                 0.146791               0.261725              0.143083
# 8                 0.030157               0.166740              0.185945
# 9                 0.087077               0.201222              0.236463
# 10                0.091840               0.237321              0.092162
# 11                0.029070               0.239941              0.061718
# 12                0.062050               0.267788              0.122691
# 13                0.094476               0.156597              0.212848
# 14                0.057178               0.182985              0.186225
# 15                0.046213               0.140187              0.158210
# 16                0.036081               0.216257              0.204011
# 17                0.126776               0.238210              0.119631
# 18                0.088289               0.224563              0.054262
# 19                0.043676               0.235162              0.280217
#
#     Dietitian_Keyword_Score  Psychologist_Skill_Score  \
# 0                  0.202016                  0.109731
# 1                  0.224514                  0.111003
# 2                  0.180220                  0.138982
# 3                  0.193625                  0.190833
# 4                  0.164989                  0.249779
# 5                  0.215586                  0.209665
# 6                  0.326331                  0.199870
# 7                  0.192215                  0.230890
# 8                  0.166751                  0.138178
# 9                  0.240487                  0.207260
# 10                 0.127249                  0.209348
# 11                 0.108715                  0.231588
# 12                 0.120159                  0.259385
# 13                 0.306182                  0.164483
# 14                 0.285848                  0.196024
# 15                 0.242832                  0.134016
# 16                 0.281078                  0.190030
# 17                 0.124320                  0.290085
# 18                 0.117223                  0.199200
# 19                 0.408028                  0.267132
#
#     Psychologist_Role_Score  Psychologist_Keyword_Score
# 0                  0.097495                    0.172200
# 1                  0.157934                    0.225362
# 2                  0.073580                   -0.014611
# 3                  0.087633                    0.118076
# 4                  0.172011                    0.039645
# 5                  0.086747                    0.078990
# 6                  0.165259                    0.103706
# 7                  0.133639                    0.067826
# 8                  0.228217                    0.174200
# 9                  0.150129                    0.080651
# 10                 0.106033                    0.082715
# 11                 0.029957                    0.005849
# 12                 0.056899                    0.056197
# 13                 0.181265                    0.117356
# 14                 0.160797                    0.144677
# 15                 0.144243                    0.146889
# 16                 0.147809                    0.151336
# 17                 0.183893                    0.161313
# 18                 0.041289                    0.104963
# 19                 0.255671                    0.167495
#
# [20 rows x 28 columns]

# %%
# Joining two dataframes - Courses and the Cosein Similarity Results based on the 'Course Id' variable. 
# Inner joins: Joins two tables with the common rows. This is a set operateion.

df_courses_score = df_courses.merge(df_cosdist, on ='Course Id', how='inner')

print(df_courses_score.shape,"\n")
# Out:
# (2213, 46)

# %%
# Tranforming and shaping the data to create the confusion matrix for the ROLE: DATA SCIENTIST

y_actu_DataScientist         = ''
y_pred_DataScientist         = ''

df_courses_score['DataScientist_Final_Score'] = (df_courses_score['DataScientist_Role_Score'] * my_role_weight) + (df_courses_score['DataScientist_Skill_Score'] * my_skill_weight)

df_courses_score['DataScientist_Predict'] = (df_courses_score['DataScientist_Final_Score'] >= my_threshold)

df_courses_score['DataScientist_Label'] = df_courses_score.Category.isin(label_DataScientist)

y_pred_DataScientist = pd.Series(df_courses_score['DataScientist_Predict'], name='Predicted')

y_actu_DataScientist = pd.Series(df_courses_score['DataScientist_Label'], name='Actual')

df_confusion_DataScientist = pd.crosstab(y_actu_DataScientist, y_pred_DataScientist , rownames=['Actual'], colnames=['Predicted'], margins=False)

# %%
# Tranforming and shaping the data to create the confusion matrix for the ROLE: SOFTWARE ENGINEER/DEVELOPER

y_actu_SoftwareDevelopment         = ''
y_pred_SoftwareDevelopment         = ''

df_courses_score['SoftwareDevelopment_Final_Score'] = (df_courses_score['SoftwareDevelopment_Role_Score'] * my_role_weight) + (df_courses_score['SoftwareDevelopment_Skill_Score'] * my_skill_weight)

df_courses_score['SoftwareDevelopment_Predict'] = (df_courses_score['SoftwareDevelopment_Final_Score'] >= my_threshold)

df_courses_score['SoftwareDevelopment_Label'] = df_courses_score.Category.isin(label_SoftwareDevelopment)

y_pred_SoftwareDevelopment = pd.Series(df_courses_score['SoftwareDevelopment_Predict'], name='Predicted')

y_actu_SoftwareDevelopment = pd.Series(df_courses_score['SoftwareDevelopment_Label'], name='Actual')

df_confusion_SoftwareDevelopment = pd.crosstab(y_actu_SoftwareDevelopment, y_pred_SoftwareDevelopment , rownames=['Actual'], colnames=['Predicted'], margins=False)

# %%
# Tranforming and shaping the data to create the confusion matrix for the ROLE: DATABASE DEVELOPER/ADMINISTRATOR

y_actu_DatabaseAdministrator         = ''
y_pred_DatabaseAdministrator         = ''

df_courses_score['DatabaseAdministrator_Final_Score'] = (df_courses_score['DatabaseAdministrator_Role_Score'] * my_role_weight) + (df_courses_score['DatabaseAdministrator_Skill_Score'] * my_skill_weight)

df_courses_score['DatabaseAdministrator_Predict'] = (df_courses_score['DatabaseAdministrator_Final_Score'] >= my_threshold)

df_courses_score['DatabaseAdministrator_Label'] = df_courses_score.Category.isin(label_DatabaseAdministrator)

y_pred_DatabaseAdministrator = pd.Series(df_courses_score['DatabaseAdministrator_Predict'], name='Predicted')

y_actu_DatabaseAdministrator = pd.Series(df_courses_score['DatabaseAdministrator_Label'], name='Actual')

df_confusion_DatabaseAdministrator = pd.crosstab(y_actu_DatabaseAdministrator, y_pred_DatabaseAdministrator , rownames=['Actual'], colnames=['Predicted'], margins=False)

# %%
# Tranforming and shaping the data to create the confusion matrix for the ROLE: CYBERSECURITY CONSULTANT

y_actu_Cybersecurity         = ''
y_pred_Cybersecurity         = ''

df_courses_score['Cybersecurity_Final_Score'] = (df_courses_score['Cybersecurity_Role_Score'] * my_role_weight) + (df_courses_score['Cybersecurity_Skill_Score'] * my_skill_weight)

df_courses_score['Cybersecurity_Predict'] = (df_courses_score['Cybersecurity_Final_Score'] >= my_threshold)

df_courses_score['Cybersecurity_Label'] = df_courses_score.Category.isin(label_Cybersecurity)

y_pred_Cybersecurity = pd.Series(df_courses_score['Cybersecurity_Predict'], name='Predicted')

y_actu_Cybersecurity = pd.Series(df_courses_score['Cybersecurity_Label'], name='Actual')

df_confusion_Cybersecurity = pd.crosstab(y_actu_Cybersecurity, y_pred_Cybersecurity , rownames=['Actual'], colnames=['Predicted'], margins=False)

# %%
# Tranforming and shaping the data to create the confusion matrix for the ROLE: FINANCIAL ACCOUNTANT

y_actu_FinancialAccountant         = ''
y_pred_FinancialAccountant         = ''

df_courses_score['FinancialAccountant_Final_Score'] = (df_courses_score['FinancialAccountant_Role_Score'] * my_role_weight) + (df_courses_score['FinancialAccountant_Skill_Score'] * my_skill_weight)

df_courses_score['FinancialAccountant_Predict'] = (df_courses_score['FinancialAccountant_Final_Score'] >= my_threshold)

df_courses_score['FinancialAccountant_Label'] = df_courses_score.Category.isin(label_FinancialAccountant)

y_pred_FinancialAccountant = pd.Series(df_courses_score['FinancialAccountant_Predict'], name='Predicted')

y_actu_FinancialAccountant = pd.Series(df_courses_score['FinancialAccountant_Label'], name='Actual')

df_confusion_FinancialAccountant = pd.crosstab(y_actu_FinancialAccountant, y_pred_FinancialAccountant , rownames=['Actual'], colnames=['Predicted'], margins=False)

# %%
# Tranforming and shaping the data to create the confusion matrix for the ROLE: MACHINE LEARNING ENGINEER

y_actu_MachineLearning         = ''
y_pred_MachineLearning         = ''

df_courses_score['MachineLearning_Final_Score'] = (df_courses_score['MachineLearning_Role_Score'] * my_role_weight) + (df_courses_score['MachineLearning_Skill_Score'] * my_skill_weight)

df_courses_score['MachineLearning_Predict'] = (df_courses_score['MachineLearning_Final_Score'] >= my_threshold)

df_courses_score['MachineLearning_Label'] = df_courses_score.Category.isin(label_MachineLearning)

y_pred_MachineLearning = pd.Series(df_courses_score['MachineLearning_Predict'], name='Predicted')

y_actu_MachineLearning = pd.Series(df_courses_score['MachineLearning_Label'], name='Actual')

df_confusion_MachineLearning = pd.crosstab(y_actu_MachineLearning, y_pred_MachineLearning , rownames=['Actual'], colnames=['Predicted'], margins=False)

# %%
# Tranforming and shaping the data to create the confusion matrix for the ROLE: MUSICIAN

y_actu_Musician         = ''
y_pred_Musician         = ''

df_courses_score['Musician_Final_Score'] = (df_courses_score['Musician_Role_Score'] * my_role_weight) + (df_courses_score['Musician_Skill_Score'] * my_skill_weight)

df_courses_score['Musician_Predict'] = (df_courses_score['Musician_Final_Score'] >= my_threshold)

df_courses_score['Musician_Label'] = df_courses_score.Category.isin(label_Musician)

y_pred_Musician = pd.Series(df_courses_score['Musician_Predict'], name='Predicted')

y_actu_Musician = pd.Series(df_courses_score['Musician_Label'], name='Actual')

df_confusion_Musician = pd.crosstab(y_actu_Musician, y_pred_Musician , rownames=['Actual'], colnames=['Predicted'], margins=False)

# %%
# Tranforming and shaping the data to create the confusion matrix for the ROLE: NUTRITIONIST/DIETITIAN

y_actu_Dietitian         = ''
y_pred_Dietitian         = ''

df_courses_score['Dietitian_Final_Score'] = (df_courses_score['Dietitian_Role_Score'] * my_role_weight) + (df_courses_score['Dietitian_Skill_Score'] * my_skill_weight)

df_courses_score['Dietitian_Predict'] = (df_courses_score['Dietitian_Final_Score'] >= my_threshold)

df_courses_score['Dietitian_Label'] = df_courses_score.Category.isin(label_Dietitian)

y_pred_Dietitian = pd.Series(df_courses_score['Dietitian_Predict'], name='Predicted')

y_actu_Dietitian = pd.Series(df_courses_score['Dietitian_Label'], name='Actual')

df_confusion_Dietitian = pd.crosstab(y_actu_Dietitian, y_pred_Dietitian , rownames=['Actual'], colnames=['Predicted'], margins=False)

# %%
df_confusion_DataScientist
# Out:
# Predicted  False  True
# Actual
# False       2071     60
# True          26     56

# %%
df_confusion_SoftwareDevelopment
# Out:
# Predicted  False  True
# Actual
# False       1511    581
# True          14    107

# %%
df_confusion_DatabaseAdministrator
# Out:
# Predicted  False  True
# Actual
# False       2103     99
# True           2      9

# %%
df_confusion_Cybersecurity
# Out:
# Predicted  False  True
# Actual
# False       2110     73
# True           0     30

# %%
df_confusion_FinancialAccountant
# Out:
# Predicted  False  True
# Actual
# False       1998    112
# True          23     80

# %%
df_confusion_MachineLearning
# Out:
# Predicted  False  True
# Actual
# False       1990    199
# True           1     23

# %%
df_confusion_Musician
# Out:
# Predicted  False  True
# Actual
# False       2163     13
# True           2     35

# %%
df_confusion_Dietitian
# Out:
# Predicted  False  True
# Actual
# False       2052    116
# True          20     25

# %%
# Performance summary for the ROLE: DATA SCIENTIST


try:
    tn_DataScientist = df_confusion_DataScientist.iloc[0][False]
except:
    tn_DataScientist = 0
    
try:
    tp_DataScientist =  df_confusion_DataScientist.iloc[1][True]
except:
    tp_DataScientist = 0

    
try:
    fn_DataScientist = df_confusion_DataScientist.iloc[1][False]
except:
    fn_DataScientist = 0
    
try:
    fp_DataScientist =  df_confusion_DataScientist.iloc[0][True]
except:
    fp_DataScientist = 0  
    
    
total_count_DataScientist = tn_DataScientist + tp_DataScientist + fn_DataScientist + fp_DataScientist

print('Data Scientist Accuracy Rate : ', '{0:.2f}'.format((tn_DataScientist + tp_DataScientist) / total_count_DataScientist * 100))

print('Data Scientist Misclassifcation Rate : ',  '{0:.2f}'.format((fn_DataScientist + fp_DataScientist) / total_count_DataScientist * 100))

print('Data Scientist True Positive Rate : ',  '{0:.2f}'.format(tp_DataScientist / (tp_DataScientist + fn_DataScientist) * 100))

print('Data Scientist False Positive Rate : ',  '{0:.2f}'.format(fp_DataScientist / (tn_DataScientist + fp_DataScientist) * 100))
# Out:
# Data Scientist Accuracy Rate :  96.11
# Data Scientist Misclassifcation Rate :  3.89
# Data Scientist True Positive Rate :  68.29
# Data Scientist False Positive Rate :  2.82

# %%
# Performance summary for the ROLE: SOFTWARE ENGINEER


try:
    tn_SoftwareDevelopment = df_confusion_SoftwareDevelopment.iloc[0][False]
except:
    tn_SoftwareDevelopment = 0
    
try:
    tp_SoftwareDevelopment =  df_confusion_SoftwareDevelopment.iloc[1][True]
except:
    tp_SoftwareDevelopment = 0

    
try:
    fn_SoftwareDevelopment = df_confusion_SoftwareDevelopment.iloc[1][False]
except:
    fn_SoftwareDevelopment = 0
    
try:
    fp_SoftwareDevelopment =  df_confusion_SoftwareDevelopment.iloc[0][True]
except:
    fp_SoftwareDevelopment = 0  
    
    
total_count_SoftwareDevelopment = tn_SoftwareDevelopment + tp_SoftwareDevelopment + fn_SoftwareDevelopment + fp_SoftwareDevelopment

print('Software Engineer Accuracy Rate : ', '{0:.2f}'.format((tn_SoftwareDevelopment + tp_SoftwareDevelopment) / total_count_SoftwareDevelopment * 100))

print('Software Engineer Misclassifcation Rate : ',  '{0:.2f}'.format((fn_SoftwareDevelopment + fp_SoftwareDevelopment) / total_count_SoftwareDevelopment * 100))

print('Software Engineer True Positive Rate : ',  '{0:.2f}'.format(tp_SoftwareDevelopment / (tp_SoftwareDevelopment + fn_SoftwareDevelopment) * 100))

print('Software Engineer False Positive Rate : ',  '{0:.2f}'.format(fp_SoftwareDevelopment / (tn_SoftwareDevelopment + fp_SoftwareDevelopment) * 100))
# Out:
# Software Engineer Accuracy Rate :  73.11
# Software Engineer Misclassifcation Rate :  26.89
# Software Engineer True Positive Rate :  88.43
# Software Engineer False Positive Rate :  27.77

# %%
# Performance summary for the ROLE: DATABASE DEVELOPER/ ADMINISTRATOR


try:
    tn_DatabaseAdministrator = df_confusion_DatabaseAdministrator.iloc[0][False]
except:
    tn_DatabaseAdministrator = 0
    
try:
    tp_DatabaseAdministrator =  df_confusion_DatabaseAdministrator.iloc[1][True]
except:
    tp_DatabaseAdministrator = 0

    
try:
    fn_DatabaseAdministrator = df_confusion_DatabaseAdministrator.iloc[1][False]
except:
    fn_DatabaseAdministrator = 0
    
try:
    fp_DatabaseAdministrator =  df_confusion_DatabaseAdministrator.iloc[0][True]
except:
    fp_DatabaseAdministrator = 0  
    
    
total_count_DatabaseAdministrator = tn_DatabaseAdministrator + tp_DatabaseAdministrator + fn_DatabaseAdministrator + fp_DatabaseAdministrator

print('Database Administrator Accuracy Rate : ', '{0:.2f}'.format((tn_DatabaseAdministrator + tp_DatabaseAdministrator) / total_count_DatabaseAdministrator * 100))

print('Database Administrator Misclassifcation Rate : ',  '{0:.2f}'.format((fn_DatabaseAdministrator + fp_DatabaseAdministrator) / total_count_DatabaseAdministrator * 100))

print('Database Administrator True Positive Rate : ',  '{0:.2f}'.format(tp_DatabaseAdministrator / (tp_DatabaseAdministrator + fn_DatabaseAdministrator) * 100))

print('Database Administrator False Positive Rate : ',  '{0:.2f}'.format(fp_DatabaseAdministrator / (tn_DatabaseAdministrator + fp_DatabaseAdministrator) * 100))
# Out:
# Database Administrator Accuracy Rate :  95.44
# Database Administrator Misclassifcation Rate :  4.56
# Database Administrator True Positive Rate :  81.82
# Database Administrator False Positive Rate :  4.50

# %%
# Performance summary for the ROLE: CYBERSECURITY CONSULTANT


try:
    tn_Cybersecurity = df_confusion_Cybersecurity.iloc[0][False]
except:
    tn_Cybersecurity = 0
    
try:
    tp_Cybersecurity =  df_confusion_Cybersecurity.iloc[1][True]
except:
    tp_Cybersecurity = 0

    
try:
    fn_Cybersecurity = df_confusion_Cybersecurity.iloc[1][False]
except:
    fn_Cybersecurity = 0
    
try:
    fp_Cybersecurity =  df_confusion_Cybersecurity.iloc[0][True]
except:
    fp_Cybersecurity = 0  
    
    
total_count_Cybersecurity = tn_Cybersecurity + tp_Cybersecurity + fn_Cybersecurity + fp_Cybersecurity

print('Cybersecurity Consultant Accuracy Rate : ', '{0:.2f}'.format((tn_Cybersecurity + tp_Cybersecurity) / total_count_Cybersecurity * 100))

print('Cybersecurity Consultant Misclassifcation Rate : ',  '{0:.2f}'.format((fn_Cybersecurity + fp_Cybersecurity) / total_count_Cybersecurity * 100))

print('Cybersecurity Consultant True Positive Rate : ',  '{0:.2f}'.format(tp_Cybersecurity / (tp_Cybersecurity + fn_Cybersecurity) * 100))

print('Cybersecurity Consultant False Positive Rate : ',  '{0:.2f}'.format(fp_Cybersecurity / (tn_Cybersecurity + fp_Cybersecurity) * 100))
# Out:
# Cybersecurity Consultant Accuracy Rate :  96.70
# Cybersecurity Consultant Misclassifcation Rate :  3.30
# Cybersecurity Consultant True Positive Rate :  100.00
# Cybersecurity Consultant False Positive Rate :  3.34

# %%
# Performance summary for the ROLE: FINANCIAL ACCOUNTANT


try:
    tn_FinancialAccountant = df_confusion_FinancialAccountant.iloc[0][False]
except:
    tn_FinancialAccountant = 0
    
try:
    tp_FinancialAccountant =  df_confusion_FinancialAccountant.iloc[1][True]
except:
    tp_FinancialAccountant = 0

    
try:
    fn_FinancialAccountant = df_confusion_FinancialAccountant.iloc[1][False]
except:
    fn_FinancialAccountant = 0
    
try:
    fp_FinancialAccountant =  df_confusion_FinancialAccountant.iloc[0][True]
except:
    fp_FinancialAccountant = 0  
    
    
total_count_FinancialAccountant = tn_FinancialAccountant + tp_FinancialAccountant + fn_FinancialAccountant + fp_FinancialAccountant

print('Financial Accountant Consultant Accuracy Rate : ', '{0:.2f}'.format((tn_FinancialAccountant + tp_FinancialAccountant) / total_count_FinancialAccountant * 100))

print('Financial Accountant Consultant Misclassifcation Rate : ',  '{0:.2f}'.format((fn_FinancialAccountant + fp_FinancialAccountant) / total_count_FinancialAccountant * 100))

print('Financial Accountant Consultant True Positive Rate : ',  '{0:.2f}'.format(tp_FinancialAccountant / (tp_FinancialAccountant + fn_FinancialAccountant) * 100))

print('Financial Accountant Consultant False Positive Rate : ',  '{0:.2f}'.format(fp_FinancialAccountant / (tn_FinancialAccountant + fp_FinancialAccountant) * 100))
# Out:
# Financial Accountant Consultant Accuracy Rate :  93.90
# Financial Accountant Consultant Misclassifcation Rate :  6.10
# Financial Accountant Consultant True Positive Rate :  77.67
# Financial Accountant Consultant False Positive Rate :  5.31

# %%
# Performance summary for the ROLE: MACHINE LEARNING ENGINEER


try:
    tn_MachineLearning = df_confusion_MachineLearning.iloc[0][False]
except:
    tn_MachineLearning = 0
    
try:
    tp_MachineLearning =  df_confusion_MachineLearning.iloc[1][True]
except:
    tp_MachineLearning = 0

    
try:
    fn_MachineLearning = df_confusion_MachineLearning.iloc[1][False]
except:
    fn_MachineLearning = 0
    
try:
    fp_MachineLearning =  df_confusion_MachineLearning.iloc[0][True]
except:
    fp_MachineLearning = 0  
    
    
total_count_MachineLearning = tn_MachineLearning + tp_MachineLearning + fn_MachineLearning + fp_MachineLearning

print('Machine Learning Engineer Accuracy Rate : ', '{0:.2f}'.format((tn_MachineLearning + tp_MachineLearning) / total_count_MachineLearning * 100))

print('Machine Learning Engineer Misclassifcation Rate : ',  '{0:.2f}'.format((fn_MachineLearning + fp_MachineLearning) / total_count_MachineLearning * 100))

print('Machine Learning Engineer True Positive Rate : ',  '{0:.2f}'.format(tp_MachineLearning / (tp_MachineLearning + fn_MachineLearning) * 100))

print('Machine Learning Engineer False Positive Rate : ',  '{0:.2f}'.format(fp_MachineLearning / (tn_MachineLearning + fp_MachineLearning) * 100))
# Out:
# Machine Learning Engineer Accuracy Rate :  90.96
# Machine Learning Engineer Misclassifcation Rate :  9.04
# Machine Learning Engineer True Positive Rate :  95.83
# Machine Learning Engineer False Positive Rate :  9.09

# %%
# Performance summary for the ROLE: MUSICIAN


try:
    tn_Musician = df_confusion_Musician.iloc[0][False]
except:
    tn_Musician = 0
    
try:
    tp_Musician =  df_confusion_Musician.iloc[1][True]
except:
    tp_Musician = 0

    
try:
    fn_Musician = df_confusion_Musician.iloc[1][False]
except:
    fn_Musician = 0
    
try:
    fp_Musician =  df_confusion_Musician.iloc[0][True]
except:
    fp_Musician = 0  
    
    
total_count_Musician = tn_Musician + tp_Musician + fn_Musician + fp_Musician

print('Musician Accuracy Rate : ', '{0:.2f}'.format((tn_Musician + tp_Musician) / total_count_Musician * 100))

print('Musician Misclassifcation Rate : ',  '{0:.2f}'.format((fn_Musician + fp_Musician) / total_count_Musician * 100))

print('Musician True Positive Rate : ',  '{0:.2f}'.format(tp_Musician / (tp_Musician + fn_Musician) * 100))

print('Musician False Positive Rate : ',  '{0:.2f}'.format(fp_Musician / (tn_Musician + fp_Musician) * 100))
# Out:
# Musician Accuracy Rate :  99.32
# Musician Misclassifcation Rate :  0.68
# Musician True Positive Rate :  94.59
# Musician False Positive Rate :  0.60

# %%
# Performance summary for the ROLE: DIETITIAN


try:
    tn_Dietitian = df_confusion_Dietitian.iloc[0][False]
except:
    tn_Dietitian = 0
    
try:
    tp_Dietitian =  df_confusion_Dietitian.iloc[1][True]
except:
    tp_Dietitian = 0

    
try:
    fn_Dietitian = df_confusion_Dietitian.iloc[1][False]
except:
    fn_Dietitian = 0
    
try:
    fp_Dietitian =  df_confusion_Dietitian.iloc[0][True]
except:
    fp_Dietitian = 0  
    
    
total_count_Dietitian = tn_Dietitian + tp_Dietitian + fn_Dietitian + fp_Dietitian

print('Dietitian Accuracy Rate : ', '{0:.2f}'.format((tn_Dietitian + tp_Dietitian) / total_count_Dietitian * 100))

print('Dietitian Misclassifcation Rate : ',  '{0:.2f}'.format((fn_Dietitian + fp_Dietitian) / total_count_Dietitian * 100))

print('Dietitian True Positive Rate : ',  '{0:.2f}'.format(tp_Dietitian / (tp_Dietitian + fn_Dietitian) * 100))

print('Dietitian False Positive Rate : ',  '{0:.2f}'.format(fp_Dietitian / (tn_Dietitian + fp_Dietitian) * 100))
# Out:
# Dietitian Accuracy Rate :  93.85
# Dietitian Misclassifcation Rate :  6.15
# Dietitian True Positive Rate :  55.56
# Dietitian False Positive Rate :  5.35

# %%
df_final_model = df_courses_score[['Course Id', 'Course Name', 'Course Description', 'Slug',
       'Provider', 'Universities/Institutions', 'Parent Subject',
       'Child Subject', 'Category', 'Url', 'Length', 'Language',
       'Credential Name', 'Rating', 'Number of Ratings', 'Certificate',
       'Workload', 'Course Keywords', 
        'DataScientist_Final_Score', 'DataScientist_Predict',
        'SoftwareDevelopment_Final_Score', 'SoftwareDevelopment_Predict', 
        'DatabaseAdministrator_Final_Score', 'DatabaseAdministrator_Predict',
        'Cybersecurity_Final_Score', 'Cybersecurity_Predict',
        'FinancialAccountant_Final_Score', 'FinancialAccountant_Predict',
        'MachineLearning_Final_Score', 'MachineLearning_Predict',
        'Musician_Final_Score', 'Musician_Predict',
        'Dietitian_Final_Score', 'Dietitian_Predict']]

# %%
df_final_model

test = df_final_model.sort_values('Dietitian_Final_Score', ascending=False)
# Out:
#       Course Id                                        Course Name  \
# 61          391  Nutrition for Health Promotion and Disease Pre...
# 170         535                    Fundamentals of Human Nutrition
# 120         478         Nutrition and Physical Activity for Health
# 289         816                        Child Nutrition and Cooking
# 169         534  Nutrition, Health, and Lifestyle: Issues and I...
# 1843       8333               Nutrition and Lifestyle in Pregnancy
# 86          419                                   Equine Nutrition
# 226         669   The New Nordic Diet - from Gastronomy to Health
# 277         733   Epidemiology: The Basic Science of Public Health
# 828        3470                    Nudge-it: Understanding obesity
# 1901       8679                                Science of Exercise
# 137         497  Exercise Physiology: Understanding the Athlete...
# 543        1808                                    The Meat We Eat
# 1945       8862               The Science of Health Care Delivery
# 292         822                The Science of Safety in Healthcare
# 493        1568  Understanding Research: An Overview for Health...
# 396        1139  Global Tuberculosis (TB) Clinical Management a...
# 1959       8921             Epidemiology in Public Health Practice
# 567        2014  Health Literacy and Communication for Health P...
# 26          346                         Basic Behavioral Neurology
# 214         655                                Social Epidemiology
# 707        2767                    Contemporary Health Informatics
# 1930       8783             Positive Psychiatry and Mental Health
# 1425       6398                        Systems Science and Obesity
# 1343       5970                              Clinical Epidemiology
# 57          387                    Principles of Obesity Economics
# 221         664                      Diabetes - a Global Challenge
# 1696       7456  HI-FIVE: Health Informatics For Innovation, Va...
# 240         685       Global Health: An Interdisciplinary Overview
# 471        1402  Sustainable Food Production Through Livestock ...
# ...         ...                                                ...
# 2072       9474                    Linear Circuits 2: AC Analysis
# 1200       5455                        Introduction to Imagemaking
# 656        2583                                        Probability
# 236         680                                      The Holocaust
# 383        1041                                    Linear Circuits
# 244         690                          History of Rock, Part One
# 2023       9235  Develop and Deploy Windows Applications on Goo...
# 245         692                          History of Rock, Part Two
# 1805       8233                     Linear Circuits 1: DC Analysis
# 1946       8866                                 The Unix Workbench
# 401        1172                           The Kennedy Half Century
# 1345       5986                           3D Printing Applications
# 1179       5411                                 Converter Circuits
# 2088       9529                               Hacking and Patching
# 189         591                                         TechniCity
# 1139       5077                Arch of Titus: Rome and the Menorah
# 635        2446            Nonlinear Dynamics 1: Geometry of Chaos
# 2131       9642                  A tecnologia da produção musical
# 990        4281                                  微积分二: 数列与级数 (中文版)
# 279         736    Unpredictable? Randomness, Chance and Free Will
# 625        2352         The Music of the Rolling Stones, 1962-1974
# 645        2478  Freedom and protest: Magna Carta and its legacies
# 971        4258                     Ruby on Rails: An Introduction
# 1296       5689              Фінанси для нефінансових спеціалістів
# 362         974                     The Fall and Rise of Jerusalem
# 1934       8804            Stalin and Stalinism in Russian History
# 1463       6622  Cities are back in town : sociología urbana pa...
# 959        4244                                        中医药与中华传统文化
# 1459       6617  Cities are back in town : sociologie urbaine p...
# 1637       7192                               Akademiskt skrivande
#
#                                      Course Description  \
# 61    This course covers the basics of normal nutrit...
# 170   This introductory course provides an overview ...
# 120   This course will provide a coherent, understan...
# 289   Eating patterns that begin in childhood affect...
# 169   This seven week course will explore nutrition ...
# 1843  Nutrition and Lifestyle in Pregnancy offers an...
# 86    This course will cover many aspects of equine ...
# 226   The New Nordic Diet is a new food culture deve...
# 277   Often called “the cornerstone” of public healt...
# 828   Nudge-it is an multi-disciplinary European res...
# 1901  Learners who complete Science of Exercise will...
# 137   Learn about the physiological responses to acu...
# 543   The Meat We Eat is a course designed to create...
# 1945  The Mayo Clinic and Arizona State University A...
# 292   Health professionals and students and health c...
# 493   Participants will learn the elements of resear...
# 396   Health Care Workers and Health Professions Stu...
# 1959  Epidemiology is often described as the corners...
# 567   In the United States, two-thirds of the popula...
# 26    This course will survey fundamental principles...
# 214   Social epidemiology is about how a society mak...
# 707   A non-technical introduction to the contempora...
# 1930  In today’s world, mental illness and distress ...
# 1425  Systems science has been instrumental in break...
# 1343  Evidence forms the basis of modern medicine. C...
# 57    The resources available to individuals and soc...
# 221   Diabetes and obesity are growing health proble...
# 1696  HI-FIVE (Health Informatics For Innovation, Va...
# 240   This course proposes an overview of current gl...
# 471   Learn about the impact of infectious disease o...
# ...                                                 ...
# 2072  This course explains how to analyze circuits t...
# 1200  During this course, we’ll be making explorator...
# 656   How should we interpret chance around us?  Wat...
# 236   This course traces the destruction of the Jews...
# 383   Learn the analysis of circuits including resis...
# 244   This course, part 1 of a 2-course sequence, ex...
# 2023  Learn to deploy and run Microsoft Windows® app...
# 245   This course, part 2 of a 2-course sequence, ex...
# 1805  This course explains how to analyze circuits t...
# 1946  Unix forms a foundation that is often very hel...
# 401   When John F. Kennedy entered the presidential ...
# 1345  This course will help you understand how 3D pr...
# 1179  This course introduces more advanced concepts ...
# 2088  In this MOOC, you will learn how to hack web a...
# 189   We live in real-time, technologically enhanced...
# 1139  The Arch of Titus: Rome and the Menorah explor...
# 635   An advanced introduction to nonlinear dynamics...
# 2131  Aprenda sobre o processo de produção musical (...
# 990   “微积分二：数列与级数”将介绍数列、无穷级数、收敛判别法和泰勒级数。本课程不仅仅满足于得到答...
# 279   This cross-disciplinary course deals with the ...
# 625   This course will survey the music of the Rolli...
# 645   This course was previously called: The Magna C...
# 971   Did you ever want to build a web application? ...
# 1296  Впливайте на ваші фінансові рішення та навчіть...
# 362   The destruction of the First Temple in Jerusal...
# 1934  The course presents the life and deeds of Jose...
# 1463  Acerca del curso\n\nLos procesos de globalizac...
# 959   谈到中华传统文化，大家首先想到的莫过于以孔子思想为代表的儒学思想，但中华传统文化绝不止这些；...
# 1459  La mondialisation et l'européanisation favoris...
# 1637  Hur lär jag mig skriva fungerande texter? Det ...
#
#                                                    Slug  Provider  \
# 61    coursera-nutrition-for-health-promotion-and-di...  Coursera
# 170            coursera-fundamentals-of-human-nutrition  Coursera
# 120   coursera-nutrition-and-physical-activity-for-h...  Coursera
# 289                coursera-child-nutrition-and-cooking  Coursera
# 169   coursera-nutrition-health-and-lifestyle-issues...  Coursera
# 1843      coursera-nutrition-and-lifestyle-in-pregnancy  Coursera
# 86                            coursera-equine-nutrition  Coursera
# 226   coursera-the-new-nordic-diet-from-gastronomy-t...  Coursera
# 277   coursera-epidemiology-the-basic-science-of-pub...  Coursera
# 828             coursera-nudge-it-understanding-obesity  Coursera
# 1901                       coursera-science-of-exercise  Coursera
# 137   coursera-exercise-physiology-understanding-the...  Coursera
# 543                            coursera-the-meat-we-eat  Coursera
# 1945       coursera-the-science-of-health-care-delivery  Coursera
# 292        coursera-the-science-of-safety-in-healthcare  Coursera
# 493   coursera-understanding-research-an-overview-fo...  Coursera
# 396   coursera-global-tuberculosis-tb-clinical-manag...  Coursera
# 1959    coursera-epidemiology-in-public-health-practice  Coursera
# 567   coursera-health-literacy-and-communication-for...  Coursera
# 26                  coursera-basic-behavioral-neurology  Coursera
# 214                        coursera-social-epidemiology  Coursera
# 707            coursera-contemporary-health-informatics  Coursera
# 1930     coursera-positive-psychiatry-and-mental-health  Coursera
# 1425               coursera-systems-science-and-obesity  Coursera
# 1343                     coursera-clinical-epidemiology  Coursera
# 57             coursera-principles-of-obesity-economics  Coursera
# 221                coursera-diabetes-a-global-challenge  Coursera
# 1696  coursera-hi-five-health-informatics-for-innova...  Coursera
# 240   coursera-global-health-an-interdisciplinary-ov...  Coursera
# 471   coursera-sustainable-food-production-through-l...  Coursera
# ...                                                 ...       ...
# 2072             coursera-linear-circuits-2-ac-analysis  Coursera
# 1200               coursera-introduction-to-imagemaking  Coursera
# 656                                coursera-probability  Coursera
# 236                              coursera-the-holocaust  Coursera
# 383                            coursera-linear-circuits  Coursera
# 244                   coursera-history-of-rock-part-one  Coursera
# 2023  coursera-develop-and-deploy-windows-applicatio...  Coursera
# 245                   coursera-history-of-rock-part-two  Coursera
# 1805             coursera-linear-circuits-1-dc-analysis  Coursera
# 1946                        coursera-the-unix-workbench  Coursera
# 401                   coursera-the-kennedy-half-century  Coursera
# 1345                  coursera-3d-printing-applications  Coursera
# 1179                        coursera-converter-circuits  Coursera
# 2088                      coursera-hacking-and-patching  Coursera
# 189                                 coursera-technicity  Coursera
# 1139        coursera-arch-of-titus-rome-and-the-menorah  Coursera
# 635     coursera-nonlinear-dynamics-1-geometry-of-chaos  Coursera
# 2131          coursera-a-tecnologia-da-producao-musical  Coursera
# 990                                         coursera---  Coursera
# 279   coursera-unpredictable-randomness-chance-and-f...  Coursera
# 625   coursera-the-music-of-the-rolling-stones-1962-...  Coursera
# 645   coursera-freedom-and-protest-magna-carta-and-i...  Coursera
# 971              coursera-ruby-on-rails-an-introduction  Coursera
# 1296                                       coursera----  Coursera
# 362             coursera-the-fall-and-rise-of-jerusalem  Coursera
# 1934   coursera-stalin-and-stalinism-in-russian-history  Coursera
# 1463  coursera-cities-are-back-in-town-sociologia-ur...  Coursera
# 959                                           coursera-  Coursera
# 1459  coursera-cities-are-back-in-town-sociologie-ur...  Coursera
# 1637                      coursera-akademiskt-skrivande  Coursera
#
#                             Universities/Institutions     Parent Subject  \
# 61            University of California, San Francisco  Health & Medicine
# 170                             University of Florida  Health & Medicine
# 120                          University of Pittsburgh  Health & Medicine
# 289                               Stanford University  Health & Medicine
# 169                             Vanderbilt University  Health & Medicine
# 1843           Ludwig-Maximilians-Universität München  Health & Medicine
# 86                            University of Edinburgh  Health & Medicine
# 226                          University of Copenhagen  Health & Medicine
# 277   The University of North Carolina at Chapel Hill  Health & Medicine
# 828                           University of Edinburgh  Health & Medicine
# 1901                   University of Colorado Boulder  Health & Medicine
# 137                           University of Melbourne  Health & Medicine
# 543                             University of Florida  Health & Medicine
# 1945                         Arizona State University  Health & Medicine
# 292                          Johns Hopkins University  Health & Medicine
# 493           University of California, San Francisco  Health & Medicine
# 396                          Johns Hopkins University  Health & Medicine
# 1959                         Johns Hopkins University  Health & Medicine
# 567                            University of Nebraska  Health & Medicine
# 26                         University of Pennsylvania            Science
# 214                           University of Minnesota  Health & Medicine
# 707                   Georgia Institute of Technology  Health & Medicine
# 1930                         The University of Sydney  Health & Medicine
# 1425                         Johns Hopkins University  Health & Medicine
# 1343                               Utrecht University  Health & Medicine
# 57                           Johns Hopkins University    Social Sciences
# 221                          University of Copenhagen  Health & Medicine
# 1696                              Columbia University  Health & Medicine
# 240                              University of Geneva  Health & Medicine
# 471        University of Illinois at Urbana-Champaign            Science
# ...                                               ...                ...
# 2072                  Georgia Institute of Technology        Engineering
# 1200                 California Institute of the Arts       Art & Design
# 656                        University of Pennsylvania        Mathematics
# 236              University of California, Santa Cruz         Humanities
# 383                   Georgia Institute of Technology        Engineering
# 244                           University of Rochester       Art & Design
# 2023                            Google Cloud|||Google        Programming
# 245                           University of Rochester       Art & Design
# 1805                  Georgia Institute of Technology        Engineering
# 1946                         Johns Hopkins University   Computer Science
# 401                            University of Virginia         Humanities
# 1345       University of Illinois at Urbana-Champaign        Engineering
# 1179                   University of Colorado Boulder        Engineering
# 2088                    University of Colorado System   Computer Science
# 189                             Ohio State University    Social Sciences
# 1139                               Yeshiva University         Humanities
# 635                   Georgia Institute of Technology        Mathematics
# 2131                         Berklee College of Music       Art & Design
# 990                             Ohio State University        Mathematics
# 279                  National University of Singapore        Mathematics
# 625                           University of Rochester       Art & Design
# 645     University of London International Programmes         Humanities
# 971                          Johns Hopkins University        Programming
# 1296                 University of California, Irvine           Business
# 362                               Tel Aviv University         Humanities
# 1934                       Higher School of Economics    Social Sciences
# 1463            Institut d'Etudes Politiques de Paris    Social Sciences
# 959                     Shanghai Jiao Tong University         Humanities
# 1459            Institut d'Etudes Politiques de Paris    Social Sciences
# 1637                                  Lund University         Humanities
#
#                  Child Subject                  Category  \
# 61        Nutrition & Wellness      Nutrition & Wellness
# 170       Nutrition & Wellness      Nutrition & Wellness
# 120       Nutrition & Wellness      Nutrition & Wellness
# 289       Nutrition & Wellness      Nutrition & Wellness
# 169       Nutrition & Wellness      Nutrition & Wellness
# 1843      Nutrition & Wellness      Nutrition & Wellness
# 86        Nutrition & Wellness      Nutrition & Wellness
# 226       Nutrition & Wellness      Nutrition & Wellness
# 277              Public Health             Public Health
# 828       Nutrition & Wellness      Nutrition & Wellness
# 1901                       NaN         Health & Medicine
# 137       Nutrition & Wellness      Nutrition & Wellness
# 543       Nutrition & Wellness      Nutrition & Wellness
# 1945               Health Care               Health Care
# 292                Health Care               Health Care
# 493                Health Care               Health Care
# 396              Public Health             Public Health
# 1959             Public Health             Public Health
# 567                Health Care               Health Care
# 26                     Biology                   Biology
# 214              Public Health             Public Health
# 707                        NaN         Health & Medicine
# 1930                       NaN         Health & Medicine
# 1425             Public Health             Public Health
# 1343       Disease & Disorders       Disease & Disorders
# 57                   Economics                 Economics
# 221        Disease & Disorders       Disease & Disorders
# 1696                       NaN         Health & Medicine
# 240              Public Health             Public Health
# 471      Environmental Science     Environmental Science
# ...                        ...                       ...
# 2072    Electrical Engineering    Electrical Engineering
# 1200       Design & Creativity       Design & Creativity
# 656                        NaN               Mathematics
# 236                    History                   History
# 383     Electrical Engineering    Electrical Engineering
# 244                      Music                     Music
# 2023        Mobile Development        Mobile Development
# 245                      Music                     Music
# 1805    Electrical Engineering    Electrical Engineering
# 1946    Information Technology    Information Technology
# 401                    History                   History
# 1345                       NaN               Engineering
# 1179    Electrical Engineering    Electrical Engineering
# 2088             Cybersecurity             Cybersecurity
# 189             Urban Planning            Urban Planning
# 1139                   History                   History
# 635                   Calculus                  Calculus
# 2131                     Music                     Music
# 990                   Calculus                  Calculus
# 279   Statistics & Probability  Statistics & Probability
# 625                      Music                     Music
# 645                    History                   History
# 971            Web Development           Web Development
# 1296                   Finance                   Finance
# 362                    History                   History
# 1934         Political Science         Political Science
# 1463            Urban Planning            Urban Planning
# 959           Foreign Language          Foreign Language
# 1459                 Sociology                 Sociology
# 1637         Grammar & Writing         Grammar & Writing
#
#                                                     Url       ...         \
# 61            https://www.coursera.org/course/nutrition       ...
# 170      https://www.coursera.org/course/humannutrition       ...
# 120   https://www.coursera.org/course/nutritionforhe...       ...
# 289       https://www.coursera.org/learn/childnutrition       ...
# 169            https://www.coursera.org/course/lifenutr       ...
# 1843  https://www.coursera.org/learn/nutrition-pregn...       ...
# 86      https://www.coursera.org/course/equinenutrition       ...
# 226      https://www.coursera.org/learn/new-nordic-diet       ...
# 277         https://www.coursera.org/learn/epidemiology       ...
# 828             https://www.coursera.org/course/nudgeit       ...
# 1901    https://www.coursera.org/learn/science-exercise       ...
# 137              https://www.coursera.org/course/exphys       ...
# 543          https://www.coursera.org/learn/meat-we-eat       ...
# 1945  https://www.coursera.org/learn/science-healthc...       ...
# 292    https://www.coursera.org/course/healthcaresafety       ...
# 493   https://www.coursera.org/course/researchforhealth       ...
# 396        https://www.coursera.org/course/tbmanagement       ...
# 1959  https://www.coursera.org/learn/epidemiology-pu...       ...
# 567      https://www.coursera.org/learn/health-literacy       ...
# 26        https://www.coursera.org/course/neurobehavior       ...
# 214           https://www.coursera.org/course/socialepi       ...
# 707    https://www.coursera.org/course/modernhealthinfo       ...
# 1930  https://www.coursera.org/learn/positive-psychi...       ...
# 1425  https://www.coursera.org/learn/systems-science...       ...
# 1343  https://www.coursera.org/learn/clinical-epidem...       ...
# 57          https://www.coursera.org/course/obesityecon       ...
# 221             https://www.coursera.org/learn/diabetes       ...
# 1696    https://www.coursera.org/learn/hi-five-clinical       ...
# 240   https://www.coursera.org/learn/global-health-o...       ...
# 471    https://www.coursera.org/learn/livestock-farming       ...
# ...                                                 ...       ...
# 2072  https://www.coursera.org/learn/linear-circuits...       ...
# 1200        https://www.coursera.org/learn/image-making       ...
# 656         https://www.coursera.org/course/probability       ...
# 236           https://www.coursera.org/course/holocaust       ...
# 383            https://www.coursera.org/course/circuits       ...
# 244      https://www.coursera.org/learn/history-of-rock       ...
# 2023  https://www.coursera.org/learn/develop-windows...       ...
# 245    https://www.coursera.org/learn/history-of-rock-2       ...
# 1805  https://www.coursera.org/learn/linear-circuits...       ...
# 1946                https://www.coursera.org/learn/unix       ...
# 401              https://www.coursera.org/learn/kennedy       ...
# 1345  https://www.coursera.org/learn/3d-printing-app...       ...
# 1179  https://www.coursera.org/learn/converter-circuits       ...
# 2088    https://www.coursera.org/learn/hacking-patching       ...
# 189            https://www.coursera.org/course/techcity       ...
# 1139         https://www.coursera.org/learn/archoftitus       ...
# 635           https://www.coursera.org/course/chaosbook       ...
# 2131  https://www.coursera.org/learn/tecnologia-prod...       ...
# 990     https://www.coursera.org/learn/gaojie-wei-jifen       ...
# 279          https://www.coursera.org/course/randomness       ...
# 625       https://www.coursera.org/learn/rolling-stones       ...
# 645          https://www.coursera.org/course/magnacarta       ...
# 971   https://www.coursera.org/learn/ruby-on-rails-i...       ...
# 1296             https://www.coursera.org/learn/finansy       ...
# 362            https://www.coursera.org/learn/jerusalem       ...
# 1934           https://www.coursera.org/learn/stalinism       ...
# 1463   https://www.coursera.org/learn/desarrollo-urbano       ...
# 959   https://www.coursera.org/learn/zhong-yi-yao-we...       ...
# 1459  https://www.coursera.org/learn/developpement-u...       ...
# 1637  https://www.coursera.org/learn/akademiskt-skri...       ...
#
#       FinancialAccountant_Label MachineLearning_Final_Score  \
# 61                        False                    0.194748
# 170                       False                    0.255470
# 120                       False                    0.258205
# 289                       False                    0.287566
# 169                       False                    0.245582
# 1843                      False                    0.208991
# 86                        False                    0.226600
# 226                       False                    0.230009
# 277                       False                    0.210857
# 828                       False                    0.275054
# 1901                      False                    0.328331
# 137                       False                    0.384096
# 543                       False                    0.191542
# 1945                      False                    0.308840
# 292                       False                    0.270990
# 493                       False                    0.278936
# 396                       False                    0.216485
# 1959                      False                    0.202528
# 567                       False                    0.308996
# 26                        False                    0.268156
# 214                       False                    0.157662
# 707                       False                    0.208771
# 1930                      False                    0.262683
# 1425                      False                    0.317985
# 1343                      False                    0.173462
# 57                        False                    0.207578
# 221                       False                    0.246442
# 1696                      False                    0.328094
# 240                       False                    0.185136
# 471                       False                    0.238759
# ...                         ...                         ...
# 2072                      False                    0.250588
# 1200                      False                    0.207366
# 656                       False                    0.200515
# 236                       False                    0.191692
# 383                       False                    0.257029
# 244                       False                    0.282950
# 2023                      False                    0.324794
# 245                       False                    0.282637
# 1805                      False                    0.229839
# 1946                      False                    0.316864
# 401                       False                    0.177358
# 1345                      False                    0.307419
# 1179                      False                    0.240300
# 2088                      False                    0.333206
# 189                       False                    0.130943
# 1139                      False                    0.156200
# 635                       False                    0.309397
# 2131                      False                    0.135424
# 990                       False                    0.083496
# 279                       False                    0.277589
# 625                       False                    0.288682
# 645                       False                    0.223929
# 971                       False                    0.285748
# 1296                       True                    0.099237
# 362                       False                    0.122073
# 1934                      False                    0.218628
# 1463                      False                    0.073987
# 959                       False                    0.073651
# 1459                      False                    0.074051
# 1637                      False                    0.040471
#
#      MachineLearning_Predict  MachineLearning_Label  Musician_Final_Score  \
# 61                     False                  False              0.118559
# 170                    False                  False              0.119219
# 120                    False                  False              0.145412
# 289                    False                  False              0.268733
# 169                    False                  False              0.197395
# 1843                   False                  False              0.180751
# 86                     False                  False              0.137374
# 226                    False                  False              0.225986
# 277                    False                  False              0.167358
# 828                    False                  False              0.181741
# 1901                   False                  False              0.152427
# 137                     True                  False              0.213630
# 543                    False                  False              0.170618
# 1945                   False                  False              0.154788
# 292                    False                  False              0.156307
# 493                    False                  False              0.148662
# 396                    False                  False              0.140754
# 1959                   False                  False              0.152952
# 567                    False                  False              0.192238
# 26                     False                  False              0.131433
# 214                    False                  False              0.169367
# 707                    False                  False              0.235408
# 1930                   False                  False              0.204696
# 1425                   False                  False              0.159408
# 1343                   False                  False              0.132740
# 57                     False                  False              0.187235
# 221                    False                  False              0.170726
# 1696                   False                  False              0.171829
# 240                    False                  False              0.152242
# 471                    False                  False              0.195507
# ...                      ...                    ...                   ...
# 2072                   False                  False              0.073638
# 1200                   False                  False              0.146846
# 656                    False                  False              0.108765
# 236                    False                  False              0.160549
# 383                    False                  False              0.106146
# 244                    False                  False              0.390160
# 2023                   False                  False              0.100755
# 245                    False                  False              0.396200
# 1805                   False                  False              0.077517
# 1946                   False                  False              0.167364
# 401                    False                  False              0.183477
# 1345                   False                  False              0.094759
# 1179                   False                  False              0.128335
# 2088                   False                  False              0.136162
# 189                    False                  False              0.101134
# 1139                   False                  False              0.202351
# 635                    False                  False              0.122354
# 2131                   False                  False              0.300699
# 990                    False                  False              0.046319
# 279                    False                  False              0.143343
# 625                    False                  False              0.440617
# 645                    False                  False              0.178697
# 971                    False                  False              0.138144
# 1296                   False                  False              0.088761
# 362                    False                  False              0.127274
# 1934                   False                  False              0.182384
# 1463                   False                  False              0.136038
# 959                    False                  False              0.077676
# 1459                   False                  False              0.120157
# 1637                   False                  False              0.044674
#
#       Musician_Predict Musician_Label Dietitian_Final_Score  \
# 61               False          False              0.705602
# 170              False          False              0.658717
# 120              False          False              0.655544
# 289              False          False              0.645862
# 169              False          False              0.640569
# 1843             False          False              0.631134
# 86               False          False              0.576836
# 226              False          False              0.572491
# 277              False          False              0.546669
# 828              False          False              0.542825
# 1901             False          False              0.520436
# 137              False          False              0.517424
# 543              False          False              0.514696
# 1945             False          False              0.511383
# 292              False          False              0.511086
# 493              False          False              0.499719
# 396              False          False              0.499426
# 1959             False          False              0.494789
# 567              False          False              0.486612
# 26               False          False              0.485607
# 214              False          False              0.479486
# 707              False          False              0.475034
# 1930             False          False              0.474442
# 1425             False          False              0.474380
# 1343             False          False              0.474361
# 57               False          False              0.472312
# 221              False          False              0.465594
# 1696             False          False              0.464342
# 240              False          False              0.463349
# 471              False          False              0.462368
# ...                ...            ...                   ...
# 2072             False          False              0.089931
# 1200             False          False              0.089094
# 656              False          False              0.088204
# 236              False          False              0.088083
# 383              False          False              0.087737
# 244               True           True              0.086685
# 2023             False          False              0.085675
# 245               True           True              0.085586
# 1805             False          False              0.083314
# 1946             False          False              0.082852
# 401              False          False              0.082523
# 1345             False          False              0.081886
# 1179             False          False              0.081845
# 2088             False          False              0.081573
# 189              False          False              0.080317
# 1139             False          False              0.075986
# 635              False          False              0.071907
# 2131             False           True              0.071566
# 990              False          False              0.068813
# 279              False          False              0.066865
# 625               True           True              0.062984
# 645              False          False              0.059191
# 971              False          False              0.059135
# 1296             False          False              0.057120
# 362              False          False              0.056310
# 1934             False          False              0.045979
# 1463             False          False              0.042027
# 959              False          False              0.036922
# 1459             False          False              0.023891
# 1637             False          False              0.002775
#
#       Dietitian_Predict  Dietitian_Label
# 61                 True             True
# 170                True             True
# 120                True             True
# 289                True             True
# 169                True             True
# 1843               True             True
# 86                 True             True
# 226                True             True
# 277                True            False
# 828                True             True
# 1901               True             True
# 137                True             True
# 543                True             True
# 1945               True            False
# 292                True            False
# 493                True            False
# 396                True            False
# 1959               True            False
# 567                True            False
# 26                 True            False
# 214                True            False
# 707                True             True
# 1930               True             True
# 1425               True            False
# 1343               True            False
# 57                 True            False
# 221                True            False
# 1696               True             True
# 240                True            False
# 471                True            False
# ...                 ...              ...
# 2072              False            False
# 1200              False            False
# 656               False            False
# 236               False            False
# 383               False            False
# 244               False            False
# 2023              False            False
# 245               False            False
# 1805              False            False
# 1946              False            False
# 401               False            False
# 1345              False            False
# 1179              False            False
# 2088              False            False
# 189               False            False
# 1139              False            False
# 635               False            False
# 2131              False            False
# 990               False            False
# 279               False            False
# 625               False            False
# 645               False            False
# 971               False            False
# 1296              False            False
# 362               False            False
# 1934              False            False
# 1463              False            False
# 959               False            False
# 1459              False            False
# 1637              False            False
#
# [2213 rows x 42 columns]

# %%
# Save the model results to the CSV File

df_final_model.columns

# def convert_to_json(fpath):
#     df_courses_score = df_courses_score.drop(df_courses_score.columns[df_courses_score.columns.str.contains('unnamed',case = False)],axis = 1)
#     df_courses_score = df_courses_score.replace(np.nan, '', regex=True)
#     df_courses_score.columns = ['courseId', 'courseName', 'courseDescription', 'slug', 'provider', 
#     'universitiesInstitutions', 'parentSubject', 'childSubject', 
#     'category', 'url', 'length', 'language', 'credentialName', 'rating', 
#     'numberOfRatings', 'certificate', 'workload', 'courseKeywords',
#     'dataScientistSkillScore', 'dataScientistRoleScore', 'dataScientistKeywordScore',
#     'softwareDevelopmentSkillScore', 'softwareDevelopmentRoleScore', 'softwareDevelopmentKeywordScore',   
#     'databaseAdministratorSkillScore', 'databaseAdministratorRoleScore', 'databaseAdministratorKeywordScore', 
#     'cybersecuritySkillScore', 'cybersecurityRoleScore', 'cybersecurityKeywordScore', 
#     'financialAccountantSkillScore', 'financialAccountantRoleScore', 'financialAccountantKeywordScore', 
#     'machineLearningSkillScore', 'machineLearningRoleScore', 'machineLearningKeywordScore', 
#     'musicianSkillScore', 'musicianRoleScore', 'musicianKeywordScore', 
#     'dietitianSkillScore', 'dietitianRoleScore', 'dietitianKeywordScore', 
#     'psychologistSkillScore', 'psychologistRoleScore', 'psychologistKeywordScore']
# Out:
# Index(['Course Id', 'Course Name', 'Course Description', 'Slug', 'Provider',
#        'Universities/Institutions', 'Parent Subject', 'Child Subject',
#        'Category', 'Url', 'Length', 'Language', 'Credential Name', 'Rating',
#        'Number of Ratings', 'Certificate', 'Workload', 'Course Keywords',
#        'DataScientist_Final_Score', 'DataScientist_Predict',
#        'DataScientist_Label', 'SoftwareDevelopment_Final_Score',
#        'SoftwareDevelopment_Predict', 'SoftwareDevelopment_Label',
#        'DatabaseAdministrator_Final_Score', 'DatabaseAdministrator_Predict',
#        'DatabaseAdministrator_Label', 'Cybersecurity_Final_Score',
#        'Cybersecurity_Predict', 'Cybersecurity_Label',
#        'FinancialAccountant_Final_Score', 'FinancialAccountant_Predict',
#        'FinancialAccountant_Label', 'MachineLearning_Final_Score',
#        'MachineLearning_Predict', 'MachineLearning_Label',
#        'Musician_Final_Score', 'Musician_Predict', 'Musician_Label',
#        'Dietitian_Final_Score', 'Dietitian_Predict', 'Dietitian_Label'],
#       dtype='object')

# %% [markdown]
# ### End of the Notebook. Thank you!
