# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk, string

# Importing required modules for EDA

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/DV/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df_courses = pd.read_csv("../Data/main_coursera.csv")

df_temp_results = pd.read_csv("../Data/temp_output.csv")


# Loading courses data from the CSV file
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-2536dc903b31> in <module>()
#       1 df_courses = pd.read_csv("../Data/main_coursera.csv")
#       2
# ----> 3 df_temp_results = pd.read_csv("../Data/temp_output.csv")
#       4
#       5
#
# ...

# %%
print(df_courses.shape,"\n")

print(df_courses.columns, "\n")

print(df_courses.info(), "\n")

print(df_courses.describe(), "\n")

print(df_temp_results.describe(), "\n")

# Exploring data dimensionality, feature names, and feature types.

# %%
df_courses = df_courses[(df_courses['Language'] == 'English')]

df_courses.head(20)

# %%
df_category_count = df_courses.groupby(by = 'Category')['Course Id'].count()

df_category_count = df_category_count.to_frame()

df_category_count = df_category_count.sort_values(by = 'Course Id', ascending = False)

df_category_count.head(50)



# df_category_count.sort_values(ascending = False)

# %%
df_courses[df_courses['Category']=='Data Science']['Course Description'].values.tolist()[1]

# %%
df_courses.count()
# Out:
# Unnamed: 0                   2213
# Course Id                    2213
# Course Name                  2213
# Course Description           2210
# Slug                         2213
# Provider                     2213
# Universities/Institutions    2212
# Parent Subject               2213
# Child Subject                1956
# Category                     2213
# Url                          2213
# Length                        964
# Language                     2213
# Credential Name               308
# Rating                       2213
# Number of Ratings            2213
# Certificate                  2089
# Workload                     1061
# dtype: int64

# %%
len(df_courses)
# Out:
# 2213

# %%
pd.unique(df_courses['Provider'])
df_courses.Category.unique()
# Out:
# array(['Databases', 'Web Development', 'Design & Creativity',
#        'Artificial Intelligence', 'Economics', 'Electrical Engineering',
#        'Sociology', 'Cybersecurity', 'Computer Science', 'Philosophy',
#        'Calculus', 'Statistics & Probability', 'Law', 'Data Science',
#        'Algorithms and Data Structures', 'Public Health', 'Finance',
#        'Biology', 'Disease & Disorders', 'Health Care', 'History',
#        'Humanities', 'Music', 'Literature', 'Quantum Mechanics',
#        'Foundations of Mathematics', 'Strategic Management',
#        'Machine Learning', 'Entrepreneurship', 'Astronomy', 'Programming',
#        'Data Analysis', 'Nutrition & Wellness', 'Education & Teaching',
#        'Science', 'Robotics', 'Environmental Science', 'Online Education',
#        'Chemistry', 'Nanotechnology', 'Psychology', 'Android Development',
#        'Physics', 'Programming Languages', 'Software Development',
#        'Big Data', 'Business Intelligence', 'Grammar & Writing',
# ...

# %%
def normalize(text):
    """
    Normalizes the text to remove the capital letters and punctuations as they hinder textual anyalsis.
    :param text: search text
    :return: returns the normalized text.
    """
    remove_punctuation_map = dict((ord(char), None) for char in string.punctuation)
    return text.lower().translate(remove_punctuation_map)


def cosine_sim(text1, text2):
    """
    Calcuates the cosine distance between the block of words.
    :param text1: Phrase 1
    :param text2: Phrase 2
    :return: returns the probabilistic measure of similarity.
    """
    vectorizer = TfidfVectorizer(tokenizer=normalize, stop_words='english')
    tfidf = vectorizer.fit_transform([text1, text2])
    return ((tfidf * tfidf.T).A)[0, 1]

# %%
cosine_sim('data science','Investigate the flexibility and power of project-oriented computational analysis, and enhance communication of information by creating visual representations of scientific data.')
# Out:
# 0.683169452438379

# %%
df_temp_results = df_temp_results.sort_values(['skill_score'], ascending = [False])

df_temp_results.nlargest(int(len(df_temp_results) * 0.1), 'skill_score')

df_cosine_merged = df_courses.merge(df_temp_results, on ='Course Id', how='inner')

df_cosine_merged = df_cosine_merged.sort_values(by = 'skill_score', ascending = False)

df_cosine_merged.sort_values(['skill_score', 'Rating'], ascending = [False, False] )
# Out:
#       Unnamed: 0  Course Id  \
# 79            93        412
# 349          563        922
# 615         1759       2289
# 215          317        656
# 6              8        316
# 2193        8303       9803
# 67            81        399
# 14            22        333
# 83            97        416
# 616         1760       2290
# 405          800       1189
# 1689        6108       7425
# 2112        8102       9587
# 94           108        427
# 1444        5345       6534
# 1148        4280       5235
# 106          120        439
# 707         2145       2767
# 107          121        440
# 49            63        379
# 1351        4920       5993
# 2072        7991       9474
# 1769        6674       8043
# 570         1536       2017
# 1924        7320       8761
# 1926        7322       8763
# 1574        5745       7030
# 84            98        417
# 13            21        332
# 346          554        913
# ...          ...        ...
# 1614        5844       7141
# ...
